# %% [markdown]
# <a href="https://colab.research.google.com/github/rouane-mouaad/FAST-Corner-Detection-Algorithm/blob/main/Data_Structures_Linear_Algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Exercice 1
# - Thief  car speed: 150 Km/h -> start time: 0 sec
# - Police car speed: 180 Km/h -> start time: 5 sec
# ### Solution:
# - Speeds and distance equations:
# - Thief:  d1 = 2.5t
# - Police: d2 = 3(t-5)
# - when d1 = d2   -----> 2.5t = 3(t-5)
# - t = 30min
# - d = 75km

# %%
thief_speed = 150/60;
police_speed = 180/60;
d_caught = 75;
t_caught = 30;

# %% [markdown]
# ## Plot the problem

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 40, 1000) # start, finish, number of points

# %%
thief_d = 2.5*t # distance traveled by the thief
police_d = 3*(t-5) # distance traveled by the thief

# %%
fig , ax = plt.subplots()
plt.grid()
plt.title("Police Chase")
plt.xlabel("time (min)")
plt.ylabel("distance (Km)")
ax.set_xlim([0,40])
ax.set_ylim([0, 100])
ax.plot(t, thief_d, color='red')
ax.plot(t, police_d, color='blue')
plt.axhline(y = d_caught, color='green', linestyle='--')
plt.axvline(x = t_caught, color='green', linestyle='--')
